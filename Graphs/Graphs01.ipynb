# %% [markdown]
# ## Importing the required libraries

# %%
import matplotlib as plt

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Making Dataset
#
# - We have used numpy to produce a normally distributed dataset which shape is (1000,1) using np.random.randn.
# - After producing we assinged the column name while loading the dataset as pandas dataframe.

# %%
df = pd.DataFrame(np.random.randn(1000),columns=['data'])

# %%
df
# Out:
#          data
# 0    0.052287
# 1    0.934578
# 2   -0.955698
# 3   -0.170526
# 4    0.426550
# ..        ...
# 995  0.850875
# 996 -1.075658
# 997  1.207622
# 998 -0.717538
# 999 -0.788938
#
# [1000 rows x 1 columns]

# %% [markdown]
# #### using plot() method
#
# - plot() method by default creates line chart.

# %%
df.plot()
# Out:
# <AxesSubplot: >

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot: >

# %%
df= pd.read_csv("https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #### Only numeric columns are plotted
# - if you want to plot categorical, you have to specify the column

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot: >

# %% [markdown]
# #### Plotting the data using bar chart

# %%
 df.iloc[5:11].plot(kind='bar',figsize = (20,10))
# Out:
# <AxesSubplot: >

# %%
 df.iloc[[5]].plot(kind='bar',figsize = (20,10))
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Horizontal bar chart
#
# - use the horizontal bar chart, when you want to see the names of the bars clearly

# %% [markdown]
#  df.iloc[5:11].plot(kind='barh',figsize = (20,10))

# %% [markdown]
# #### Histogram
#
# - Histogram plots the graph, keeping data points on x-axis and frequency on y-axis
# - It is used to know the frequency of the range of data points.

# %%
df.plot(kind='hist')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
 df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df['sepal_length'].plot(kind='hist')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df['sepal_length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
df.sepal_length.describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal_length, dtype: float64

# %%
df.hist(figsize=(20,10),color='r',bins=10)
# Out:
# array([[<AxesSubplot: title={'center': 'sepal_length'}>,
#         <AxesSubplot: title={'center': 'sepal_width'}>],
#        [<AxesSubplot: title={'center': 'petal_length'}>,
#         <AxesSubplot: title={'center': 'petal_width'}>]], dtype=object)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #### Box plot
#
# - Used for identifying the outliers in the dataset

# %%
df.plot(kind = 'box',figsize = (20,10))
# Out:
# <AxesSubplot: >

# %% [markdown]
# #### Area plot

# %%
df.plot(kind='area',figsize=(20,10))
# Out:
# <AxesSubplot: >

# %%
df.plot(figsize=(20,10),alpha =0.5)
# Out:
# <AxesSubplot: >

# %% [markdown]
# #### Scatter plot
#
# - Used to identify the co-relation of two variables

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length')
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# #### Scatter plot with three variables

# %%
df.plot.scatter(x = 'sepal_length', y = 'petal_length',c = 'sepal_width')
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# #### Pie chart
#
# - Use only when you have 4 to 5 categories in the feature

# %%
df.drop(columns='species').iloc[0].plot(kind= 'pie')
# Out:
# <AxesSubplot: ylabel='0'>

# %%
# !pip install plotly

# %%
import plotly as plt

# %%
# !pip install cufflinks

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df.iplot()
# Out:
# <div>                            <div id="6d76585f-85a4-4343-a8b4-3b811f93e027" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='sepal_length',y= 'petal_length', mode = 'markers')
# Out:
# <div>                            <div id="f824ca5d-e3b6-4ea6-b4c5-d368c84ac418" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="303a17d9-11aa-4320-8cb7-41d078912890" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.head().iplot(kind = 'scatter3d',x = "sepal_length",y = "sepal_width",z = "petal_length")
# Out:
# <div>                            <div id="c8f4196e-c73d-418b-9c97-be55cf1138bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
