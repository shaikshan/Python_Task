# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/MainakRepositor/Datasets/refs/heads/master/Chennai%20rain/chennai_reservoir_levels.csv")

# %%
df
# Out:
#             Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM
# 0     01-01-2004     3.9         0.0     268.0              0.0
# 1     02-01-2004     3.9         0.0     268.0              0.0
# 2     03-01-2004     3.9         0.0     267.0              0.0
# 3     04-01-2004     3.9         0.0     267.0              0.0
# 4     05-01-2004     3.8         0.0     267.0              0.0
# ...          ...     ...         ...       ...              ...
# 6177  29-11-2020  2814.0       403.0    2819.0           3120.0
# 6178  30-11-2020  2848.0       465.0    2833.0           3120.0
# 6179  01-12-2020  2902.0       504.0    2841.0           3123.0
# 6180  02-12-2020  2873.0       547.0    2847.0           3125.0
# 6181  03-12-2020  2867.0       590.0    2878.0           3137.0
#
# [6182 rows x 5 columns]

# %%
pd.read_csv("https://raw.githubusercontent.com/MainakRepositor/Datasets/refs/heads/master/Chennai%20rain/chennai_reservoir_levels.csv",
        
        header=None)
# Out:
#                0        1           2         3                4
# 0           Date   POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM
# 1     01-01-2004     3.90        0.00    268.00             0.00
# 2     02-01-2004     3.90        0.00    268.00             0.00
# 3     03-01-2004     3.90        0.00    267.00             0.00
# 4     04-01-2004     3.90        0.00    267.00             0.00
# ...          ...      ...         ...       ...              ...
# 6178  29-11-2020  2814.00      403.00   2819.00          3120.00
# 6179  30-11-2020  2848.00      465.00   2833.00          3120.00
# 6180  01-12-2020  2902.00      504.00   2841.00          3123.00
# 6181  02-12-2020  2873.00      547.00   2847.00          3125.00
# 6182  03-12-2020  2867.00      590.00   2878.00          3137.00
#
# [6183 rows x 5 columns]

# %%
df =pd.read_csv("https://raw.githubusercontent.com/MainakRepositor/Datasets/refs/heads/master/Chennai%20rain/chennai_reservoir_levels.csv")

# %%
df.columns
# Out:
# Index(['Date', 'POONDI', 'CHOLAVARAM', 'REDHILLS', 'CHEMBARAMBAKKAM'], dtype='object')

# %%
df
# Out:
#             Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM
# 0     01-01-2004     3.9         0.0     268.0              0.0
# 1     02-01-2004     3.9         0.0     268.0              0.0
# 2     03-01-2004     3.9         0.0     267.0              0.0
# 3     04-01-2004     3.9         0.0     267.0              0.0
# 4     05-01-2004     3.8         0.0     267.0              0.0
# ...          ...     ...         ...       ...              ...
# 6177  29-11-2020  2814.0       403.0    2819.0           3120.0
# 6178  30-11-2020  2848.0       465.0    2833.0           3120.0
# 6179  01-12-2020  2902.0       504.0    2841.0           3123.0
# 6180  02-12-2020  2873.0       547.0    2847.0           3125.0
# 6181  03-12-2020  2867.0       590.0    2878.0           3137.0
#
# [6182 rows x 5 columns]

# %%
df1 = df[['Date', 'POONDI', 'CHOLAVARAM']]

# %%
df1
# Out:
#             Date  POONDI  CHOLAVARAM
# 0     01-01-2004     3.9         0.0
# 1     02-01-2004     3.9         0.0
# 2     03-01-2004     3.9         0.0
# 3     04-01-2004     3.9         0.0
# 4     05-01-2004     3.8         0.0
# ...          ...     ...         ...
# 6177  29-11-2020  2814.0       403.0
# 6178  30-11-2020  2848.0       465.0
# 6179  01-12-2020  2902.0       504.0
# 6180  02-12-2020  2873.0       547.0
# 6181  03-12-2020  2867.0       590.0
#
# [6182 rows x 3 columns]

# %%
df1.boxplot()
# Out:
# <AxesSubplot: >

# %%
df.dtypes
# Out:
# Date                object
# POONDI             float64
# CHOLAVARAM         float64
# REDHILLS           float64
# CHEMBARAMBAKKAM    float64
# dtype: object

# %%
df.sum().isnull()
# Out:
# Date               False
# POONDI             False
# CHOLAVARAM         False
# REDHILLS           False
# CHEMBARAMBAKKAM    False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Date               0
# POONDI             0
# CHOLAVARAM         0
# REDHILLS           0
# CHEMBARAMBAKKAM    0
# dtype: int64

# %%
df.head()
# Out:
#          Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM
# 0  01-01-2004     3.9         0.0     268.0              0.0
# 1  02-01-2004     3.9         0.0     268.0              0.0
# 2  03-01-2004     3.9         0.0     267.0              0.0
# 3  04-01-2004     3.9         0.0     267.0              0.0
# 4  05-01-2004     3.8         0.0     267.0              0.0

# %%
df.tail()
# Out:
#             Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM
# 6177  29-11-2020  2814.0       403.0    2819.0           3120.0
# 6178  30-11-2020  2848.0       465.0    2833.0           3120.0
# 6179  01-12-2020  2902.0       504.0    2841.0           3123.0
# 6180  02-12-2020  2873.0       547.0    2847.0           3125.0
# 6181  03-12-2020  2867.0       590.0    2878.0           3137.0

# %%
df.describe()
# Out:
#             POONDI   CHOLAVARAM     REDHILLS  CHEMBARAMBAKKAM
# count  6182.000000  6182.000000  6182.000000      6182.000000
# mean   1106.739588   226.404589  1592.321652      1321.460555
# std    1004.555050   266.886855   915.243744       951.791133
# min       0.900000     0.000000     0.000000         0.000000
# 25%     202.000000    26.000000   847.250000       459.250000
# 50%     783.150000    89.000000  1685.000000      1264.000000
# 75%    1918.000000   411.000000  2320.000000      2046.750000
# max    3231.000000   896.000000  3300.000000      3396.000000

# %%
df.to_csv('Chennai_Data')

# %%
df.corr()
# Out:
# C:\Users\Munna\AppData\Local\Temp\ipykernel_26032\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM
# POONDI           1.000000    0.823638  0.754660         0.852809
# CHOLAVARAM       0.823638    1.000000  0.690272         0.776602
# REDHILLS         0.754660    0.690272  1.000000         0.862498
# CHEMBARAMBAKKAM  0.852809    0.776602  0.862498         1.000000
